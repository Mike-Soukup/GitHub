# %%
# Script explaining how to perform linear regression in Python with a dataset from Kaggle in a file USA_Housing.csv

#First import modules needed for functionality
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

af30 = pd.read_excel('Copy of 1000X88 3M Blend Data history.xlsx', 'Regression Data AF-30')
af30.head()
#Yield [=] % Is the dependent variable Y
#Independent variabls will be the Mooney buckets/Lot
# Out:
#       Lot   AF-30 Lot  0-10  11-20  21-30  31-40  41-50  51-60  61-70  71-80  \
# 0  1D6D527        NaN     0      0      0      1      2      2      1      1
# 1  1D6D528        NaN     0      0      0      0      1      1      1      0
# 2  1D08J82        NaN     0      0      1      0      0      2      0      0
# 3  1D09L01        NaN     0      0      0      0      0      0      2      1
# 4  1D10L58        NaN     0      0      0      0      0      0      2      0
#
#    ...  111-120  121-130  131-140  Shrinkage  Pinholes             Comments  \
# 0  ...        3        0        0        0.0       0.0                 Good
# 1  ...        0        0        0        0.0       0.0                 Good
# 2  ...        0        3        0        0.0       0.0                 Good
# 3  ...        0        0        0        1.0       1.0  Holes and shrinkage
# 4  ...        0        1        0        0.0       0.0             Too hard
#
# ...

# %%
sns.distplot(af30['Yield [=] %'])

# %%
af30.corr()
# Out:
#                  AF-30 Lot  0-10  11-20     21-30     31-40     41-50  \
# AF-30 Lot              NaN   NaN    NaN       NaN       NaN       NaN
# 0-10                   NaN   NaN    NaN       NaN       NaN       NaN
# 11-20                  NaN   NaN    NaN       NaN       NaN       NaN
# 21-30                  NaN   NaN    NaN  1.000000 -0.142857 -0.236433
# 31-40                  NaN   NaN    NaN -0.142857  1.000000  0.709299
# 41-50                  NaN   NaN    NaN -0.236433  0.709299  1.000000
# 51-60                  NaN   NaN    NaN  0.203653  0.203653  0.187251
# 61-70                  NaN   NaN    NaN -0.462910 -0.308607 -0.255377
# 71-80                  NaN   NaN    NaN -0.378824 -0.090196 -0.308507
# 81-90                  NaN   NaN    NaN -0.162650 -0.162650 -0.269191
# 91-100                 NaN   NaN    NaN -0.322873  0.538122  0.415618
# 101-110                NaN   NaN    NaN  0.789690  0.087743  0.016135
# ...

# %%
corr = af30.corr()
sns.heatmap(corr)

# %%
af30.head()
af30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 23 columns):
# Lot                16 non-null object
# AF-30 Lot          0 non-null float64
# 0-10               16 non-null int64
# 11-20              16 non-null int64
# 21-30              16 non-null int64
# 31-40              16 non-null int64
# 41-50              16 non-null int64
# 51-60              16 non-null int64
# 61-70              16 non-null int64
# 71-80              16 non-null int64
# 81-90              16 non-null int64
# 91-100             16 non-null int64
# 101-110            16 non-null int64
# 111-120            16 non-null int64
# 121-130            16 non-null int64
# 131-140            16 non-null int64
# Shrinkage          12 non-null float64
# Pinholes           12 non-null float64
# Comments           13 non-null object
# Total Charge       16 non-null int64
# Color Grade        0 non-null float64
# Yield [=] %        16 non-null float64
# ...

# %%
af30=af30.drop(columns = "AF-30 Lot")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-a8ce450e3fcc> in <module>
# ----> 1 af30=af30.drop(columns = "AF-30 Lot")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
af30.head()
# Out:
#       Lot   0-10  11-20  21-30  31-40  41-50  51-60  61-70  71-80  81-90  ...  \
# 0  1D6D527     0      0      0      1      2      2      1      1      0  ...
# 1  1D6D528     0      0      0      0      1      1      1      0      0  ...
# 2  1D08J82     0      0      1      0      0      2      0      0      1  ...
# 3  1D09L01     0      0      0      0      0      0      2      1      2  ...
# 4  1D10L58     0      0      0      0      0      0      2      0      2  ...
#
#    111-120  121-130  131-140  Shrinkage  Pinholes             Comments  \
# 0        3        0        0        0.0       0.0                 Good
# 1        0        0        0        0.0       0.0                 Good
# 2        0        3        0        0.0       0.0                 Good
# 3        0        0        0        1.0       1.0  Holes and shrinkage
# 4        0        1        0        0.0       0.0             Too hard
#
#    Total Charge Color Grade  Yield [=] %  Shrinkage [=] %
# ...

# %%
af30=af30.drop(columns="Color Grade")
af30.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-e88cdd7aa1f4> in <module>
# ----> 1 af30=af30.drop(columns="Color Grade")
#       2 af30.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
af30.head()
af30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 21 columns):
# Lot                16 non-null object
# 0-10               16 non-null int64
# 11-20              16 non-null int64
# 21-30              16 non-null int64
# 31-40              16 non-null int64
# 41-50              16 non-null int64
# 51-60              16 non-null int64
# 61-70              16 non-null int64
# 71-80              16 non-null int64
# 81-90              16 non-null int64
# 91-100             16 non-null int64
# 101-110            16 non-null int64
# 111-120            16 non-null int64
# 121-130            16 non-null int64
# 131-140            16 non-null int64
# Shrinkage          12 non-null float64
# Pinholes           12 non-null float64
# Comments           13 non-null object
# Total Charge       16 non-null int64
# Yield [=] %        16 non-null float64
# Shrinkage [=] %    0 non-null float64
# dtypes: float64(4), int64(15), object(2)
# ...

# %%
af30=af30.drop(columns=['Shrinkage','Pinholes','Comments','Shrinkage [=] %'])

# %%
af30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 17 columns):
# Lot             16 non-null object
# 0-10            16 non-null int64
# 11-20           16 non-null int64
# 21-30           16 non-null int64
# 31-40           16 non-null int64
# 41-50           16 non-null int64
# 51-60           16 non-null int64
# 61-70           16 non-null int64
# 71-80           16 non-null int64
# 81-90           16 non-null int64
# 91-100          16 non-null int64
# 101-110         16 non-null int64
# 111-120         16 non-null int64
# 121-130         16 non-null int64
# 131-140         16 non-null int64
# Total Charge    16 non-null int64
# Yield [=] %     16 non-null float64
# dtypes: float64(1), int64(15), object(1)
# memory usage: 2.2+ KB

# %%
sns.pairplot(af30)

# %%
corr = af30.corr()
sns.heatmap(corr)
