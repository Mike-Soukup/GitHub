# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("spreadspoke_scores.csv")

# %%
data
# Out:
#       schedule_date  schedule_season schedule_week             team_home  \
# 0        09/02/1966             1966             1        Miami Dolphins
# 1        09/03/1966             1966             1        Houston Oilers
# 2        09/04/1966             1966             1    San Diego Chargers
# 3        09/09/1966             1966             2        Miami Dolphins
# 4        09/10/1966             1966             1     Green Bay Packers
# 5        09/10/1966             1966             2        Houston Oilers
# 6        09/10/1966             1966             2    San Diego Chargers
# 7        09/11/1966             1966             1       Atlanta Falcons
# 8        09/11/1966             1966             2         Buffalo Bills
# 9        09/11/1966             1966             1         Detroit Lions
# 10       09/11/1966             1966             1   Pittsburgh Steelers
# 11       09/11/1966             1966             1   San Francisco 49ers
# ...
